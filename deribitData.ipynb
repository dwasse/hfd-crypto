# %%
import config
from databaseController import DatabaseController

# %%
db = DatabaseController()

# %%
result = db.execute("SELECT * FROM Orders AS result;")

# %%
print(result.fetchall())
# Out:
# [(1, {'id': 42, 'usIn': 1567889318222940, 'usOut': 1567889318222973, 'result': ['book.BTC-PERPETUAL.100ms'], 'usDiff': 33, 'jsonrpc': '2.0', 'testnet': False}), (2, {'method': 'subscription', 'params': {'data': {'asks': [['new', 10514.0, 300250.0], ['new', 10514.5, 62540.0], ['new', 10515.0, 52030.0], ['new', 10515.5, 40500.0], ['new', 10516.0, 8640.0], ['new', 10516.5, 22800.0], ['new', 10517.0, 47930.0], ['new', 10517.5, 30.0], ['new', 10518.0, 5340.0], ['new', 10518.5, 10250.0], ['new', 10519.0, 32960.0], ['new', 10519.5, 65000.0], ['new', 10520.0, 11880.0], ['new', 10520.5, 60240.0], ['new', 10521.0, 115230.0], ['new', 10521.5, 36860.0], ['new', 10522.0, 244730.0], ['new', 10522.5, 11660.0], ['new', 10523.0, 73820.0], ['new', 10523.5, 300820.0], ['new', 10524.0, 6770.0], ['new', 10524.5, 65610.0], ['new', 10525.0, 177490.0], ['new', 10525.5, 5670.0], ['new', 10526.0, 34190.0], ['new', 10526.5, 100050.0], ['new', 10527.0, 390.0], ['new', 10527.5, 10100.0], ['new', 10528.0, 167040.
# ...
